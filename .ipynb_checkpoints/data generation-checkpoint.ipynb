# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
import seaborn as sns
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
plt.rcParams['figure.figsize'] = [8, 8]

# %%
n_samples = 26
random_state = 2**14

# %%
X, y = make_classification(n_samples=n_samples, random_state=random_state,
                          n_features=3, n_redundant=0, n_informative=3,
                          n_clusters_per_class=1, class_sep=1.0)

# %%
# scaling to [-1, 1] range
X_max = np.max(X, axis=0)
X_min = np.min(X, axis=0)
X = 1 - 2 * (X - X_min)/(X_max - X_min)

# %%
feature_names = ['x1', 'x2', 'x3']
data = pd.DataFrame(X, columns=feature_names)
data['y'] = y
data.head()
# Out:
#          x1        x2        x3  y
# 0 -0.279979 -0.228180 -0.204855  0
# 1  0.002869  0.683811  0.220064  1
# 2 -0.032465  0.918332 -0.416806  1
# 3  0.010268  0.538407  0.867916  1
# 4  0.306242  0.857358 -0.915058  0

# %%
data.describe()
# Out:
#               x1         x2         x3          y
# count  26.000000  26.000000  26.000000  26.000000
# mean    0.005319   0.246173   0.147274   0.500000
# std     0.466624   0.572595   0.563906   0.509902
# min    -1.000000  -1.000000  -1.000000   0.000000
# 25%    -0.372811  -0.171250  -0.271360   0.000000
# 50%     0.062359   0.365550   0.264128   0.500000
# 75%     0.273796   0.710221   0.523279   1.000000
# max     1.000000   1.000000   1.000000   1.000000

# %%
g = sns.PairGrid(data, hue='y')
g.map(plt.scatter)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=3, random_state=random_state)
model.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=3,
#                        n_jobs=None, oob_score=False, random_state=16384,
#                        verbose=0, warm_start=False)

# %%
y_pred = model.predict(X)
acc = np.count_nonzero(y_pred == y) / n_samples
print('Accuracy on train set = {}'.format(acc))
# Out:
# Accuracy on train set = 0.9615384615384616

# %%
plt.scatter(X[:, 0], X[:, 1], c=y_pred)
plt.title('Predictions from RF - 2 out of 3 features')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

# %%
from sklearn.tree import export_graphviz
from graphviz import Source

# %%
digraphs = []

for estimator in model.estimators_:
    dot = export_graphviz(estimator,
                feature_names = feature_names,
                class_names = ['0', '1'],
                rounded = True, proportion = False, 
                precision = 2, filled = True)
    digraphs.append(Source(dot))

# %%
digraphs[0]

# %%
digraphs[1]

# %%
digraphs[2]
